# %% [markdown]
# # ドリルA: 基礎30問 — 変数・リスト・ループ・if・関数 🏋️
#
# **対応レッスン: 1〜3。** 手を動かして文法を体に入れるためのドリルです。進め方:
#
# 1. 問題を読む → **まず自分で書く**(5〜10分悩んでOK。悩んでいる時間に力がつきます)
# 2. 実行して「期待される出力」と一致すれば正解
# 3. 解けても解けなくても、**一番下の解答の解説コメントを読む**(別解や「なぜそう書くか」を載せています。正解した問題でも読む価値あり)
# 4. 詰まったら: どのレッスンの内容かを各問題に書いてあるので、そこを見直す → それでも詰まったら書きかけのコードをClaudeへ
#
# 目安: Q1〜10は1問2分、Q11〜25は1問5分、Q26〜30は1問10分。
#
# ---
# ## ウォームアップ (Q1〜Q10) 【レッスン1の範囲: 変数・計算・print・f文字列】

# %% [markdown]
# ### Q1
#
# `Hello, drill!` と表示せよ。

# %%
# ここに書く

# %% [markdown]
# ### Q2
#
# `365 * 24` の結果を表示せよ。→ 期待: `8760`

# %%
# ここに書く

# %% [markdown]
# ### Q3
#
# 変数 `hours_per_day = 24`, `days = 7` を作り、1週間の時間数を表示せよ。→ `168`

# %%
# ここに書く

# %% [markdown]
# ### Q4
#
# `x = 3`, `y = 8` を作った後、**2つの変数の中身を入れ替えて** `print(x, y)` せよ。→ `8 3`(ヒント: 一時変数 `tmp` を使う。Python流の1行技もある)

# %%
# ここに書く

# %% [markdown]
# ### Q5
#
# `d_mm = 1500` (mm) をkmに変換して表示せよ。→ `1.5e-06` ではなく `0.0000015` でもなく…実行して出た表記が正しいか自分で判断せよ(どちらも同じ値)。

# %%
# ここに書く

# %% [markdown]
# ### Q6
#
# `a = 10, b = 3` の割り算の商を小数で、さらに `a % b`(余り)も表示せよ。→ `3.3333333333333335` と `1`

# %%
# ここに書く

# %% [markdown]
# ### Q7
#
# 身長 `h = 1.72` (m)、体重 `w = 65` (kg) からBMI = w / h² を計算し、`f"BMI: {bmi:.1f}"` の形式で表示せよ。→ `BMI: 22.0`

# %%
# ここに書く

# %% [markdown]
# ### Q8
#
# `price = 128000` を `f"価格: {price:,} 円"` 形式で表示せよ。→ `価格: 128,000 円`

# %%
# ここに書く

# %% [markdown]
# ### Q9
#
# リスト `[3, 1, 4, 1, 5, 9, 2, 6]` を変数に入れ、最初・最後・前から3番目の要素を1行ずつ表示せよ。→ `3` `6` `4`

# %%
# ここに書く

# %% [markdown]
# ### Q10
#
# 上のリストの要素数を `len()` で、合計を `sum()` で、最大を `max()` で表示せよ。→ `8` `31` `9`

# %%
# ここに書く

# %% [markdown]
# ---
# ## 基礎体力 (Q11〜Q25) 【レッスン2〜3の範囲: リスト・ループ・if・関数】

# %% [markdown]
# ### Q11
#
# リスト `[3, 1, 4, 1, 5, 9, 2, 6]` のスライスで「先頭3個」「最後2個」「両端を除いた中身」を表示せよ。→ `[3, 1, 4]` `[2, 6]` `[1, 4, 1, 5, 9, 2]`

# %%
# ここに書く

# %% [markdown]
# ### Q12
#
# forループで `1` から `5` を1行ずつ表示せよ。

# %%
# ここに書く

# %% [markdown]
# ### Q13
#
# forループで `10, 8, 6, 4, 2` を1行ずつ表示せよ。(ヒント: `range(始, 終, 刻み)` は刻みにマイナスも使える)

# %%
# ここに書く

# %% [markdown]
# ### Q14
#
# 1〜100の合計をforループで計算して表示せよ(`sum()`禁止)。→ `5050`

# %%
# ここに書く

# %% [markdown]
# ### Q15
#
# 空リストに `append` で 1〜10 の2乗を貯めて、最後にリストごと表示せよ。→ `[1, 4, 9, 16, 25, 36, 49, 64, 81, 100]`

# %%
# ここに書く

# %% [markdown]
# ### Q16
#
# `while` を使って、2を何回も2倍していき、**初めて10000を超えた値**を表示せよ。→ `16384`

# %%
# ここに書く

# %% [markdown]
# ### Q17
#
# `score = 85` に対し、80以上なら`A`、60以上なら`B`、それ未満なら`C`と表示するif文を書け。→ `A`(scoreを70, 50に変えても正しく動くこと)

# %%
# ここに書く

# %% [markdown]
# ### Q18
#
# `n = 24` が「2でも3でも割り切れる」なら `OK` と表示せよ(`and` を使う)。→ `OK`

# %%
# ここに書く

# %% [markdown]
# ### Q19
#
# リスト `[12, 5, 8, 130, 44, 7]` から**偶数だけ**を1行ずつ表示せよ。→ `12 8 130 44`(各行)

# %%
# ここに書く

# %% [markdown]
# ### Q20
#
# 同じリストから偶数だけを**新しいリストに集めて**表示せよ。→ `[12, 8, 130, 44]`(Q15とQ19の合わせ技)

# %%
# ここに書く

# %% [markdown]
# ### Q21
#
# リスト `[12, 5, 8, 130, 44, 7]` の最大値を **max()禁止で** forとifで求めよ。→ `130`

# %%
# ここに書く

# %% [markdown]
# ### Q22
#
# 引数の3倍を返す関数 `triple(x)` を定義し、`triple(7)` と `triple(1.5)` を表示せよ。→ `21` `4.5`

# %%
# ここに書く

# %% [markdown]
# ### Q23
#
# 2辺 `a, b` から直角三角形の斜辺 √(a²+b²) を返す関数 `hypotenuse(a, b)` を書き、`hypotenuse(3, 4)` を表示せよ。→ `5.0`(ヒント: 平方根は `** 0.5`)

# %%
# ここに書く

# %% [markdown]
# ### Q24
#
# 税込価格を返す関数 `with_tax(price, rate=0.10)` を書き、`with_tax(1000)` と `with_tax(1000, rate=0.08)` を表示せよ。→ `1100.0` `1080.0`

# %%
# ここに書く

# %% [markdown]
# ### Q25
#
# リストを受け取り平均を返す関数 `mean(values)` を書け。空リストなら `None` を返すこと。`mean([2, 4, 9])` と `mean([])` を表示。→ `5.0` `None`

# %%
# ここに書く

# %% [markdown]
# ---
# ## 実戦 (Q26〜Q30) 【総合: 実務の頻出パターン】

# %% [markdown]
# ### Q26
#
# **FizzBuzz改**: 1〜50で、4の倍数は `Hop`、6の倍数は `Step`、両方(12の倍数)は `Jump` を、それ以外は数を表示せよ。最初の12行 → `1 2 3 Hop 5 Step 7 Hop 9 10 11 Jump`

# %%
# ここに書く

# %% [markdown]
# ### Q27
#
# 九九の表を「行ごとに横並び」で表示せよ。ヒント: `print(f"{i*j:3}", end="")` で改行なし出力、行末で `print()`。
#
# 期待(先頭行): `  1  2  3  4  5  6  7  8  9`

# %%
# ここに書く

# %% [markdown]
# ### Q28
#
# `kion = [22.1, 25.3, 28.0, 26.4, 21.9, 19.8, 23.5]`(1週間の気温)について、(1)平均を小数1桁で (2)25℃を超えた日数 (3)最高気温が何日目か(1始まり)を表示せよ。→ `平均: 23.9` `真夏日っぽい日: 3日` `最高: 3日目`

# %%
# ここに書く

# %% [markdown]
# ### Q29
#
# 関数 `count_between(values, low, high)`: リストのうち low以上high以下の個数を返す。`count_between([12, 5, 8, 130, 44, 7], 5, 50)` → `5`

# %%
# ここに書く

# %% [markdown]
# ### Q30
#
# **ミニプロジェクト: 貯金シミュレータ**
#
# 関数 `months_to_goal(monthly, goal)` を書け:
# - 毎月 `monthly` 円ずつ貯金し、貯金額が `goal` 円以上になるまで何ヶ月かかるかをwhileで数えて返す
# - `monthly` が0以下なら `raise ValueError("毎月の貯金額は正の値が必要です")`
#
# 確認: `months_to_goal(30000, 1000000)` → `34`、`months_to_goal(0, 100)` はtry/exceptで受けてエラーメッセージを表示。

# %%
# ここに書く

# %% [markdown]
# ---
# ## 💡 解答(答え合わせは全問解いてから!)
#
# <details>
# <summary>Q1〜Q10</summary>
#
# ```python
# # Q1
# print("Hello, drill!")
# # Q2
# print(365 * 24)
# # Q3
# hours_per_day = 24
# days = 7
# print(hours_per_day * days)
# # Q4 「入れ替え」は一時変数に退避してから上書きする。直接 x = y とすると元のxが消えるため
# x = 3
# y = 8
# tmp = x
# x = y
# y = tmp
# print(x, y)        # Python流: x, y = y, x でも可
# # Q5
# d_mm = 1500
# print(d_mm / 1000 / 1000)   # 1.5e-06 (= 0.0000015 km)
# # Q6
# a = 10
# b = 3
# print(a / b)
# print(a % b)
# # Q7
# h = 1.72
# w = 65
# bmi = w / h ** 2
# print(f"BMI: {bmi:.1f}")
# # Q8
# price = 128000
# print(f"価格: {price:,} 円")
# # Q9
# nums = [3, 1, 4, 1, 5, 9, 2, 6]
# print(nums[0])
# print(nums[-1])
# print(nums[2])
# # Q10
# print(len(nums), )
# print(sum(nums))
# print(max(nums))
# ```
# </details>
#
# <details>
# <summary>Q11〜Q25</summary>
#
# ```python
# # Q11
# nums = [3, 1, 4, 1, 5, 9, 2, 6]
# print(nums[:3])
# print(nums[-2:])
# print(nums[1:-1])
# # Q12
# for i in range(1, 6):
#     print(i)
# # Q13
# for i in range(10, 0, -2):
#     print(i)
# # Q14
# total = 0
# for i in range(1, 101):
#     total = total + i
# print(total)
# # Q15
# squares = []
# for i in range(1, 11):
#     squares.append(i ** 2)
# print(squares)
# # Q16
# x = 2
# while x <= 10000:
#     x = x * 2
# print(x)
# # Q17
# score = 85
# if score >= 80:
#     print("A")
# elif score >= 60:
#     print("B")
# else:
#     print("C")
# # Q18
# n = 24
# if n % 2 == 0 and n % 3 == 0:
#     print("OK")
# # Q19
# for v in [12, 5, 8, 130, 44, 7]:
#     if v % 2 == 0:
#         print(v)
# # Q20
# evens = []
# for v in [12, 5, 8, 130, 44, 7]:
#     if v % 2 == 0:
#         evens.append(v)
# print(evens)
# # Q21 「暫定チャンピオン方式」: 先頭を暫定最大とし、勝った値が現れたら交代。最小値・最長文字列など何にでも応用できる超重要パターン
# values = [12, 5, 8, 130, 44, 7]
# biggest = values[0]
# for v in values:
#     if v > biggest:
#         biggest = v
# print(biggest)
# # Q22
# def triple(x):
#     return x * 3
# print(triple(7))
# print(triple(1.5))
# # Q23
# def hypotenuse(a, b):
#     return (a ** 2 + b ** 2) ** 0.5
# print(hypotenuse(3, 4))
# # Q24
# def with_tax(price, rate=0.10):
#     return price * (1 + rate)
# print(with_tax(1000))
# print(with_tax(1000, rate=0.08))
# # Q25
# def mean(values):
#     if len(values) == 0:
#         return None
#     return sum(values) / len(values)
# print(mean([2, 4, 9]))
# print(mean([]))
# ```
# </details>
#
# <details>
# <summary>Q26〜Q30</summary>
#
# ```python
# # Q26 判定は「厳しい条件(12の倍数)から先に」。4や6を先に書くと12の倍数がそちらに吸われてJumpに到達しない
# for i in range(1, 51):
#     if i % 12 == 0:
#         print("Jump")
#     elif i % 4 == 0:
#         print("Hop")
#     elif i % 6 == 0:
#         print("Step")
#     else:
#         print(i)
# # Q27
# for i in range(1, 10):
#     for j in range(1, 10):
#         print(f"{i*j:3}", end="")
#     print()
# # Q28
# kion = [22.1, 25.3, 28.0, 26.4, 21.9, 19.8, 23.5]
# print(f"平均: {sum(kion) / len(kion):.1f}")
# count = 0
# for t in kion:
#     if t > 25:
#         count = count + 1
# print(f"真夏日っぽい日: {count}日")
# best_day = 0
# for i in range(len(kion)):
#     if kion[i] > kion[best_day]:
#         best_day = i
# print(f"最高: {best_day + 1}日目")
# # Q29
# def count_between(values, low, high):
#     count = 0
#     for v in values:
#         if low <= v <= high:      # 比較は連結できる
#             count = count + 1
#     return count
# print(count_between([12, 5, 8, 130, 44, 7], 5, 50))
# # Q30 「入口で検証(fail fast)→whileで状態を更新しながら数える」実務の定番構造
# def months_to_goal(monthly, goal):
#     if monthly <= 0:
#         raise ValueError("毎月の貯金額は正の値が必要です")
#     saved = 0
#     months = 0
#     while saved < goal:
#         saved = saved + monthly
#         months = months + 1
#     return months
#
# print(months_to_goal(30000, 1000000))
# try:
#     months_to_goal(0, 100)
# except ValueError as e:
#     print("エラー:", e)
# ```
# </details>
